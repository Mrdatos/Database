# %%
#lo mejor de la vida es aprender
logica = 3
if logica > 1:
    print (f"es mayor a {logica}")
else:
    print("nada")
# Out:
# es mayor a 3

# %%
import sys

print(sys.version)
# Out:
# 3.12.12 (main, Nov 18 2025, 05:56:04) [GCC 14.2.0]

# %%
if 5 > 2:
 print("Five is greater than two!") 
if 5 > 2:
        print("Five is greater than two!")
# Out:
# Five is greater than two!
# Five is greater than two!

# %%
vendedores = ['ana', 'luis', 'marta', 'sergio']
vendedores[2]= 'cero'
print(vendedores)
#las listas pueden ser editables
# Out:
# ['ana', 'luis', 'cero', 'sergio']

# %%
vendedores[2] += 5
print(vendedores)
#el += solo se debe usar con variales tipo numericas

# %%
vendedores.append(4)
vendedores[4]+=5
print(vendedores)
# Out:
# ['ana', 'luis', 'cero', 'sergio', 9]

# %%
meses = []
ventas = []

cantidad_meses = int(input("ingrese el numero de meses a registrar: "))
for i in range (cantidad_meses):
    mes = ("ingrese el nombre del mes: ")
    venta = (f"ingrese el total de ventas en {mes}: ")

    #guardar los datos
    meses.append(mes)
    ventas.append(venta)
